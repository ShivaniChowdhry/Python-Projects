# %%
# Assign the initial values
balance = float(input('What is your starting balance?'))
deposit = float(input('Your monthly deposit amount?'))
rate    = float(input('What is your interest rate?')) /100.0/12.0
years   = int(input('Over how many years?'))
#
print('Fund by years (' + str(rate*100*12) + '% annual interest rate)')
print('Year \t Fund')
for y in range(years):
    for m in range(12):
        balance = (balance + deposit) * (1+rate) 
        # Display the result
    #
    print(str(y+1) + '\t${:,.2f}'.format(balance))
#
flag    = input('Calculate length until you to become a millionaire? (Y/N):')
#
yesAnswers = ['Y', 'YES']
noAnswers  = ['N', 'NO']
if flag.upper() in yesAnswers:
    balance = 0
    year = 1
    while year > 0:
        for m in range(12):
            balance = (balance + deposit) * (1+rate)
        if balance < 1000000:
            year +=1
        else:
            break
    #
    out = 'You will become a millionaire in {} years'.format(str(year))
    print(out)
elif flag.upper() in noAnswers:
    print('Thanks for playing! ')
else:
    print('Your input is unavailable.')
# Out:
# What is your starting balance?0
# Your monthly deposit amount?500
# What is your interest rate?10
# Over how many years?30
# Fund by years (10.0% annual interest rate)
# Year 	 Fund
# 1	$6,335.14
# 2	$13,333.65
# 3	$21,065.00
# 4	$29,605.92
# 5	$39,041.19
# 6	$49,464.45
# 7	$60,979.17
# 8	$73,699.63
# 9	$87,752.08
# 10	$103,276.01
# 11	$120,425.50
# 12	$139,370.76
# 13	$160,299.84
# 14	$183,420.47
# 15	$208,962.13
# 16	$237,178.34
# 17	$268,349.15
# 18	$302,783.95
# 19	$340,824.53
# 20	$382,848.45
# 21	$429,272.83
# 22	$480,558.45
# 23	$537,214.34
# 24	$599,802.84
# 25	$668,945.17
# 26	$745,327.62
# 27	$829,708.30
# 28	$922,924.74
# 29	$1,025,902.16
# 30	$1,139,662.66
# Calculate length until you to become a millionaire? (Y/N):yes
# You will become a millionaire in 29 years

# %%
# Assign the initial values
balance = float(input('What is your starting balance?'))
deposit = float(input('Your monthly deposit amount?'))
rate    = float(input('What is your interest rate?')) /100.0/12.0
years   = int(input('Over how many years?'))
#
print('Fund by years (' + str(rate*100*12) + '% annual interest rate)')
print('Year \t Fund')
for y in range(years):
    for m in range(12):
        balance = (balance + deposit) * (1+rate) 
        # Display the result
    #
    print(str(y+1) + '\t${:,.2f}'.format(balance))
#
flag    = input('Calculate length until you to become a millionaire? (Y/N):')
#
yesAnswers = ['Y', 'YES']
noAnswers  = ['N', 'NO']
if flag.upper() in yesAnswers:
    balance = 0
    year = 1
    while year > 0:
        for m in range(12):
            balance = (balance + deposit) * (1+rate)
        if balance < 1000000:
            year +=1
        else:
            break
    #
    out = 'You will become a millionaire in {} years'.format(str(year))
    print(out)
elif flag.upper() in noAnswers:
    print('Thanks for playing! ')
else:
    print('Your input is unavailable.')
#
flag_rate = input('Display fund by interest rate table?(Y/N):')
if flag_rate.upper() in yesAnswers:
    print('Fund by interest rate ({} years)'.format(str(years)))
    print('Rate \t Fund')
    
    rate_list = [i for i in range(1,31)]
    for r in rate_list:
        balance = 0
        rate = r /100.0/12.0
        for y in range(years):
            for m in range(12):
                balance = (balance + deposit) * (1+rate)
        #
        print('{}%'.format(str(r)) + '\t${:,.2f}'.format(balance))
elif flag_rate.upper() in noAnswers:
    print('Thanks for playing! ')
else:
    print('Your input is unavailable.')
# Out:
# What is your starting balance?0
# Your monthly deposit amount?500
# What is your interest rate?5
# Over how many years?30
# Fund by years (5.0% annual interest rate)
# Year 	 Fund
# 1	$6,165.01
# 2	$12,645.43
# 3	$19,457.40
# 4	$26,617.89
# 5	$34,144.72
# 6	$42,056.64
# 7	$50,373.34
# 8	$59,115.55
# 9	$68,305.02
# 10	$77,964.64
# 11	$88,118.47
# 12	$98,791.79
# 13	$110,011.17
# 14	$121,804.56
# 15	$134,201.32
# 16	$147,232.33
# 17	$160,930.02
# 18	$175,328.51
# 19	$190,463.66
# 20	$206,373.15
# 21	$223,096.61
# 22	$240,675.66
# 23	$259,154.09
# 24	$278,577.92
# 25	$298,995.50
# 26	$320,457.69
# 27	$343,017.92
# 28	$366,732.37
# 29	$391,660.11
# 30	$417,863.19
# Calculate length until you to become a millionaire? (Y/N):y
# You will become a millionaire in 45 years
# Display fund by interest rate table?(Y/N):y
# Fund by interest rate (30 years)
# Rate 	 Fund
# 1%	$209,988.95
# 2%	$246,773.30
# 3%	$292,096.86
# 4%	$348,181.45
# 5%	$417,863.19
# 6%	$504,768.81
# 7%	$613,543.75
# ...

# %%
print('Year \t Fund')
print('1998'+'\t500.23')
# Out:
# Year 	 Fund
# 1998	500.23
